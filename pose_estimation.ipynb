# %%
import matplotlib.pyplot as plt
fig, ax1=plt.subplots()

co_ordinates=['l_elbow','r_elbow','l_shoulder','r_shoulder']
correct=[142.47,149.28,96.00,99.21]
#pose1=[91.43,91.00,148.27,135.83]
pose2=[112.03,118.76,114.19,113.42]

ax1.plot(co_ordinates,correct,'bo--')
ax2=ax1.twinx()
#ax3=ax1.twinx()

ax2.plot(co_ordinates,pose2,'ro--')
#ax3.plot(co_ordinates,pose2,'ko')
ax1.set_xlabel('joint locations')
ax1.set_ylabel('joint angles : Correct')
ax2.set_ylabel('Joint angles: predicted')
plt.title('pose variance graph')
ax1.legend(['correct'],loc=0)
ax2.legend(['predicted'],loc=0)
plt.show()

# %%
from statistics import mean 

mean_c=mean(correct)
mean_p=mean(predicted)

deflection= mean
from statistics import mean 
​
mean_c=mean(correct)
mean_p=mean(predicted)
​
deflection= mean_p-mean_c
​
print(abs(deflection))
    
44.6075_p-mean_c

print(abs(deflection))
# Out:
#   File "C:\Users\RAJARS~1\AppData\Local\Temp/ipykernel_2064/3057435533.py", line 8
#     ​
#     ^
# SyntaxError: invalid non-printable character U+200B

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RAJARS~1\AppData\Local\Temp/ipykernel_7564/213309543.py in <module>
#      12 ax2.plot(co_ordinates,predicted,'ro--')
#      13 ax3=(ax1).twinx
# ---> 14 ax3=plot(co_ordinates,mean,'go--')
#      15
#      16 ax1.set_xlabel('joint locations')
#
# NameError: name 'plot' is not defined

# %%
import matplotlib.pyplot as plt

x=[0.54]
y=[0.33]
z=[-0.16]

plt.plot(x,y, marker="o", markersize=20, markeredgecolor="red",
markerfacecolor="green")
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#correct points
x=[0.54, 0.47, 0.55, 0.46, 0.52,0.46, 0.49, 0.36,0.48,0.46]
y=[0.33,0.33,0.21,0.21,0.57,0.55,0.74,0.64,0.90,0.62]
z=[-0.16,-0.1,-0.26,-0.14,-0.03, 0.03, 0.01,-0.1,0.16,0.21]
# ax2 = fig.add_subplot(111, projection='3d')
#incorrect points
a=[0.62, 0.49, 0.67,0.45,0.57,0.49,0.55,0.41,0.52,0.55]
b=[0.37, 0.37,0.3,0.29,0.56,0.55,0.69,0.66,0.8,0.63]
c=[-0.16,-0.01,-0.33,-0.05,-0.06,0.06,-0.002,0.03,0.21,0.58]
# ax.scatter(0.54, 0.33, -0.16)
ax.plot(x,y,z,"go--")
# ax2=ax.twinx()
ax.plot(a,b,c,"ro--")
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#ax=Axes3D(fig)
#correct points
x=[0.54, 0.47, 0.55, 0.46, 0.52,0.46, 0.49, 0.36,0.48,0.46]
y=[0.33,0.33,0.21,0.21,0.57,0.55,0.74,0.64,0.90,0.62]
z=[-0.16,-0.1,-0.26,-0.14,-0.03, 0.03, 0.01,-0.1,0.16,0.21]
dx=[0.1]
dy=[0.1]
dz=[0.1]
# ax2 = fig.add_subplot(111, projection='3d')
#incorrect points
a=[0.62, 0.49, 0.67,0.45,0.57,0.49,0.55,0.41,0.52,0.55]
b=[0.37, 0.37,0.3,0.29,0.56,0.55,0.69,0.66,0.8,0.63]
c=[-0.16,-0.01,-0.33,-0.05,-0.06,0.06,-0.002,0.03,0.21,0.58]
da=[0.1]
db=[0.1]
dc=[0.1]
# ax.scatter(0.54, 0.33, -0.16)
ax.bar3d(x,y,z,dx,dy,dz, color='g')
# ax2=ax.twinx()
ax.bar3d(a,b,c,da,db,dc, color='r')
plt.show()
